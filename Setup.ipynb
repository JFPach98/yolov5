# %% [markdown]
# # Setup

# %%
import os
import shutil
import numpy as np
import random
import itertools

# %% [markdown]
# Se obtiene una lista de las imágenes y de las labels.

# %%
labels = os.listdir('./labels')
images = os.listdir('./dataset')

# %% [markdown]
# Se randomiza la lista 'labels' para crear el dataset de entrenamiento y el de pruebas. Se hace un split de 75-25 % para los datasets.

# %%
train_labels = []
test_labels = []

randomized = labels[:]
random.shuffle(labels)

quarter = len(labels)//4
quarter

train_labels = labels[quarter:]
test_labels = labels[:quarter]

# %%
train_labels
# Out:
# ['2020-03-12_10-39-17.txt',
#  '2019-07-24_14-52-45.xml.txt',
#  '2018-05-12_11-39-18.xml.txt',
#  '2020-03-19_12-12-48.txt',
#  '2020-03-19_12-10-03.txt',
#  '2018-05-30_15-01-11.xml.txt',
#  '2018-05-12_11-39-00.txt',
#  '2020-03-19_12-12-45.txt',
#  '2020-02-27_10-37-59.txt',
#  '2020-03-20_11-19-09.txt',
#  '2020-06-24_12-05-03.xml.txt',
#  '2020-03-12_10-31-51.txt',
#  '2018-05-29_16-14-54.txt',
#  '2020-03-20_12-07-51.txt',
#  '2020-03-20_11-05-26.txt',
#  '2020-03-19_12-05-11.txt',
#  '2020-06-30_12-28-30.txt',
#  '2020-03-20_12-23-25.txt',
#  '2020-06-30_12-29-15.txt',
#  '2020-03-20_10-16-06.txt',
#  '2018-05-30_15-00-38.xml.txt',
#  '2020-02-27_10-30-31.txt',
#  '2019-07-24_14-52-52.xml.txt',
#  '2018-05-29_15-44-34.txt',
#  '2019-09-18_10-40-39.txt',
#  '2020-03-20_10-24-17.txt',
#  '2019-07-24_14-36-10.txt',
#  '2019-07-24_14-36-15.txt',
#  '2018-12-18_10-50-30.txt',
#  '2018-05-30_14-58-20.xml.txt',
#  '2018-05-29_16-14-43.txt',
#  '2020-02-27_10-27-11.txt',
# ...

# %% [markdown]
# Se crea el dataset de entrenamiento, con las direcciones de las imágenes.

# %%
train_images = []

for x in train_labels:
    image = x.replace('.txt', '.JPG')
    train_images.append(image)

train_images
# Out:
# ['2020-03-12_10-39-17.JPG',
#  '2019-07-24_14-52-45.xml.JPG',
#  '2018-05-12_11-39-18.xml.JPG',
#  '2020-03-19_12-12-48.JPG',
#  '2020-03-19_12-10-03.JPG',
#  '2018-05-30_15-01-11.xml.JPG',
#  '2018-05-12_11-39-00.JPG',
#  '2020-03-19_12-12-45.JPG',
#  '2020-02-27_10-37-59.JPG',
#  '2020-03-20_11-19-09.JPG',
#  '2020-06-24_12-05-03.xml.JPG',
#  '2020-03-12_10-31-51.JPG',
#  '2018-05-29_16-14-54.JPG',
#  '2020-03-20_12-07-51.JPG',
#  '2020-03-20_11-05-26.JPG',
#  '2020-03-19_12-05-11.JPG',
#  '2020-06-30_12-28-30.JPG',
#  '2020-03-20_12-23-25.JPG',
#  '2020-06-30_12-29-15.JPG',
#  '2020-03-20_10-16-06.JPG',
#  '2018-05-30_15-00-38.xml.JPG',
#  '2020-02-27_10-30-31.JPG',
#  '2019-07-24_14-52-52.xml.JPG',
#  '2018-05-29_15-44-34.JPG',
#  '2019-09-18_10-40-39.JPG',
#  '2020-03-20_10-24-17.JPG',
#  '2019-07-24_14-36-10.JPG',
#  '2019-07-24_14-36-15.JPG',
#  '2018-12-18_10-50-30.JPG',
#  '2018-05-30_14-58-20.xml.JPG',
#  '2018-05-29_16-14-43.JPG',
#  '2020-02-27_10-27-11.JPG',
# ...

# %% [markdown]
# Y el dataset de prueba.

# %%
test_images = []

for x in test_labels:
    image = x.replace('.txt', '.JPG')
    test_images.append(image)

test_images
# Out:
# ['2018-05-30_14-54-16.xml.JPG',
#  '2018-05-29_16-14-01.JPG',
#  '2020-03-20_10-25-07.JPG',
#  '2020-06-24_11-35-12.JPG',
#  '2020-03-19_13-17-32.JPG',
#  '2020-06-30_12-29-00.JPG',
#  '2020-03-20_10-26-22.JPG',
#  '2018-05-12_11-38-48.JPG',
#  '2018-05-29_15-46-00.JPG',
#  '2020-06-24_12-05-09.xml.JPG',
#  '2020-03-20_10-21-47.JPG',
#  '2019-09-18_11-47-19.JPG',
#  '2018-05-28_13-54-41.JPG',
#  '2020-06-30_13-59-21.JPG',
#  '2020-03-19_12-11-43.JPG',
#  '2018-05-12_11-39-39.xml.JPG',
#  '2020-02-27_10-25-44.xml.JPG',
#  '2020-06-30_13-37-53.JPG',
#  '2018-05-12_12-22-13.JPG',
#  '2020-03-19_12-47-32.JPG',
#  '2020-03-19_12-13-58.JPG',
#  '2020-03-19_13-34-18.JPG',
#  '2019-07-24_18-08-39.JPG',
#  '2019-07-24_14-44-09.JPG',
#  '2020-03-19_13-45-02.JPG',
#  '2018-05-28_13-51-22.JPG',
#  '2018-05-12_11-38-30.JPG',
#  '2018-05-12_12-21-52.JPG',
#  '2018-05-12_11-39-38.xml.JPG',
#  '2018-05-12_11-39-49.JPG',
#  '2018-05-29_12-27-01.JPG',
#  '2018-05-12_11-39-23.JPG',
# ...

# %% [markdown]
# Se mueven los datasets en a su respectiva carpeta:

# %%
data = os.listdir('./dataset')
lab = os.listdir('./lab')
for (x, y) in zip(data, lab):
    shutil.move('./dataset/' + x, './testing/test/images/')
    shutil.move('./lab/' + y, './testing/test/labels/' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-0a35effa3885> in <module>
# ----> 1 data = os.listdir('./dataset')
#       2 lab = os.listdir('./lab')
#       3 for (x, y) in zip(data, lab):
#       4     shutil.move('./dataset/' + x, './testing/test/images/')
#       5     shutil.move('./lab/' + y, './testing/test/labels/' )
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './dataset'

# %%
for (x, y) in zip(train_images, train_labels):
    shutil.move('./dataset/' + x, './data/train/images/')
    shutil.move('./labels/' + y, './data/train/labels/' )
for (x, y) in zip(test_images, test_labels):
    shutil.move('./dataset/' + x, './data/test/images/')
    shutil.move('./labels/' + y, './data/test/labels/' )
